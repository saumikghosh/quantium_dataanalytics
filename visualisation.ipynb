# %% [markdown]
# <a href="https://colab.research.google.com/github/saumikghosh/quantium_dataanalytics/blob/main/visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
QVI=pd.read_csv("QVI_data.csv")
QVI.head()
# Out:
#    LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0            1000  2018-10-17          1       1         5
# 1            1002  2018-09-16          1       2        58
# 2            1003  2019-03-07          1       3        52
# 3            1003  2019-03-08          1       4       106
# 4            1004  2018-11-02          1       5        96
#
#                                 PROD_NAME  PROD_QTY  TOT_SALES  PACK_SIZE  \
# 0  Natural Chip        Compny SeaSalt175g         2        6.0        175
# 1   Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7        150
# 2   Grain Waves Sour    Cream&Chives 210G         1        3.6        210
# 3  Natural ChipCo      Hony Soy Chckn175g         1        3.0        175
# 4          WW Original Stacked Chips 160g         1        1.9        160
#
#         BRAND              LIFESTAGE PREMIUM_CUSTOMER
# 0     NATURAL  YOUNG SINGLES/COUPLES          Premium
# 1         RRD  YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
chips=QVI[QVI["PROD_NBR"]==5]
chips.describe() #the statistical measure of the chips category
# Out:
#        LYLTY_CARD_NBR    STORE_NBR         TXN_ID  PROD_NBR     PROD_QTY  \
# count    1.468000e+03  1468.000000    1468.000000    1468.0  1468.000000
# mean     1.345512e+05   132.823569  132832.793597       5.0     1.891689
# std      9.593782e+04    76.934002   78035.441284       0.0     0.392307
# min      1.000000e+03     1.000000       1.000000       5.0     1.000000
# 25%      6.905400e+04    69.000000   66174.500000       5.0     2.000000
# 50%      1.241290e+05   122.000000  127869.500000       5.0     2.000000
# 75%      1.961360e+05   196.000000  196270.500000       5.0     2.000000
# max      2.330171e+06   271.000000  269550.000000       5.0     5.000000
#
#          TOT_SALES  PACK_SIZE
# count  1468.000000     1468.0
# mean      5.675068      175.0
# std       1.176922        0.0
# min       3.000000      175.0
# 25%       6.000000      175.0
# 50%       6.000000      175.0
# 75%       6.000000      175.0
# max      15.000000      175.0

# %%
chips=QVI[QVI["PROD_NBR"]==5]
chips.head(10000)
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000  2018-10-17          1       1         5
# 30                1024  2019-02-20          1      31         5
# 166               1150  2019-04-14          1     176         5
# 343               1314  2019-02-13          1     357         5
# 564               1501  2018-08-07          1     581         5
# ...                ...         ...        ...     ...       ...
# 263751          271160  2018-07-09        271  269147         5
# 263932          271187  2019-06-06        271  269333         5
# 264040          271207  2019-02-26        271  269443         5
# 264146          271223  2018-10-02        271  269550         5
# 264809         2330171  2019-06-20         77  236737         5
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# 0       Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
df=pd.DataFrame(QVI)
df['c']=(df['TOT_SALES']-3)//12
df.describe()
# Out:
#        LYLTY_CARD_NBR      STORE_NBR        TXN_ID       PROD_NBR  \
# count    2.648340e+05  264834.000000  2.648340e+05  264834.000000
# mean     1.355488e+05     135.079423  1.351576e+05      56.583554
# std      8.057990e+04      76.784063  7.813292e+04      32.826444
# min      1.000000e+03       1.000000  1.000000e+00       1.000000
# 25%      7.002100e+04      70.000000  6.760050e+04      28.000000
# 50%      1.303570e+05     130.000000  1.351365e+05      56.000000
# 75%      2.030940e+05     203.000000  2.026998e+05      85.000000
# max      2.373711e+06     272.000000  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES      PACK_SIZE              c
# count  264834.000000  264834.000000  264834.000000  264834.000000
# mean        1.905813       7.299346     182.425512      -0.023524
# std         0.343436       2.527241      64.325148       0.167739
# min         1.000000       1.500000      70.000000      -1.000000
# ...

# %%
chips=QVI[QVI["PROD_NBR"]==5]
df=pd.DataFrame(QVI)
df['c']=(df['TOT_SALES']-5.67)//12
df.describe()
# added the metric to see
# Out:
#        LYLTY_CARD_NBR      STORE_NBR        TXN_ID       PROD_NBR  \
# count    2.648340e+05  264834.000000  2.648340e+05  264834.000000
# mean     1.355488e+05     135.079423  1.351576e+05      56.583554
# std      8.057990e+04      76.784063  7.813292e+04      32.826444
# min      1.000000e+03       1.000000  1.000000e+00       1.000000
# 25%      7.002100e+04      70.000000  6.760050e+04      28.000000
# 50%      1.303570e+05     130.000000  1.351365e+05      56.000000
# 75%      2.030940e+05     203.000000  2.026998e+05      85.000000
# max      2.373711e+06     272.000000  2.415841e+06     114.000000
#
#             PROD_QTY      TOT_SALES      PACK_SIZE              c
# count  264834.000000  264834.000000  264834.000000  264834.000000
# mean        1.905813       7.299346     182.425512      -0.257418
# std         0.343436       2.527241      64.325148       0.440396
# min         1.000000       1.500000      70.000000      -1.000000
# ...

# %%
df=pd.DataFrame(QVI)
df['c']=(df['TOT_SALES']-5.67)//12
chips=QVI[QVI["PROD_NBR"]==5]
df.head(1500) #also got the graphs to have insights regarding the store counter number
# Out:
#       LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0               1000  2018-10-17          1       1         5
# 1               1002  2018-09-16          1       2        58
# 2               1003  2019-03-07          1       3        52
# 3               1003  2019-03-08          1       4       106
# 4               1004  2018-11-02          1       5        96
# ...              ...         ...        ...     ...       ...
# 1495            3104  2019-01-22          3    1530       113
# 1496            3104  2019-03-11          3    1531        20
# 1497            3104  2019-06-23          3    1532        17
# 1498            3105  2018-08-13          3    1533        49
# 1499            3105  2018-09-28          3    1534        81
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES  \
# 0       Natural Chip        Compny SeaSalt175g         2        6.0
# 1        Red Rock Deli Chikn&Garlic Aioli 150g         1        2.7
# ...
